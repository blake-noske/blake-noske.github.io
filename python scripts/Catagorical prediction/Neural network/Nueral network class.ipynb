# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import joblib
from sklearn.datasets import make_classification
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV, cross_val_score,TimeSeriesSplit
from sklearn.pipeline import Pipeline
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
from scipy.stats import uniform, randint
from sklearn.compose import ColumnTransformer
import os

# %%
# Load the dataset
os.chdir('C:\\Users\\blake\\Desktop\\AFL Odds\\cleaned data')
match_results = pd.read_csv('afl_match_results_cleaned.csv')
os.chdir('C:\\Users\\blake\\Desktop\\AFL Odds\\python scripts\\Catagorical prediction\\Neural network')

# Define the features and the target variable
weather_dummies = pd.get_dummies(match_results['weather.weatherType'])
X = match_results.drop(columns=['match.homeTeam.name', 'match.awayTeam.name','venue.name','Margin','Result','weather.weatherType']).astype('float64')  # Drop irrelevant columns
X = pd.concat([X, weather_dummies], axis=1)
y = match_results['Result']  # BW, LW, D, LL, BL

# Assuming 'weather_columns' is a list of your dummy weather variables
weather_columns = weather_dummies.columns  # Replace with actual weather columns
discrete_columns = ['Home.Team.Venue.Win.Streak', 'Away.Team.Venue.Win.Streak','Home.Win.Streak'] 
continuous_columns = [col for col in X.columns if col not in weather_columns and col not in discrete_columns]

# ColumnTransformer to apply StandardScaler only to continuous features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), continuous_columns),
        ('disc', MinMaxScaler(), discrete_columns),
        ('weather', 'passthrough', weather_columns)  # Weather columns are passed through unchanged
    ]
)

# Initialize LabelEncoder
encoder = LabelEncoder()

# Fit and transform the target variable
y_encoded = encoder.fit_transform(y)

cutoff_index = int(0.8 * len(match_results))

# Create the training set (first 80%) and validation set (last 20%)
X_train = X
y_train = y

y_train_encoded = encoder.fit_transform(y_train)

# Standardize the features
X_train = preprocessor.fit_transform(X_train)

# %% [markdown]
# ### Run at beginning of season

# %%
# # Function to create the Keras model
# def create_model(optimizer='adam', dropout_rate=0.3, neurons=64, learn_rate=0.01):
#     model = Sequential([
#         Dense(neurons, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.001), input_dim=X_train.shape[1]),
#         BatchNormalization(),
#         Dropout(dropout_rate),
#         Dense(32, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.001)),
#         BatchNormalization(),
#         Dropout(dropout_rate),
#         Dense(16, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
#         BatchNormalization(),
#         Dropout(dropout_rate),
#         Dense(5, kernel_initializer='he_uniform', activation='softmax')
#     ])
#     model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learn_rate, name=optimizer), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return model


# # Create the KerasClassifier wrapper
# model = KerasClassifier(build_fn=create_model, verbose=0)

# # Define the grid of hyperparameters to search
# param_grid = {
#     'batch_size': [32, 64, 128],
#     'epochs': [20, 30, 50],
#     'optimizer': ['adam', 'sgd'],
#     'dropout_rate': [0.2, 0.3, 0.5],
#     'neurons': [32, 64, 128],
#     'learn_rate': [0.001, 0.01, 0.1]
# }

# # Use KFold cross-validation
# kfold = KFold(n_splits=3, shuffle=True, random_state=42)

# # Initialize GridSearchCV
# grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# # Fit the model using GridSearchCV
# grid_result = grid.fit(X_train, y_train)

# # Summarize results
# print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")

# # Evaluate on the test set
# best_model = grid_result.best_estimator_.model
# test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
# print(f"Test Accuracy: {test_accuracy:.4f}")

# %% [markdown]
# ### Continue programming

# %%
# Define artificial neural network
def create_simplified_model(input_dim):
    model = Sequential([
        Dense(128, kernel_initializer='he_uniform', activation='relu', input_dim=input_dim, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(16, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(5, kernel_initializer='he_uniform', activation='softmax')
    ])
    
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1,name='adam'), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Define TimeSeriesSplit with the desired number of splits
n_splits = 5  # You can adjust the number of splits
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize a list to store accuracies from each fold
accuracy_scores = []

# Perform time-aware cross-validation
for train_index, test_index in tscv.split(X_train):
    # Split the data into training and validation sets based on the time split
    X_train_cv, X_test_cv = X_train[train_index], X_train[test_index]
    y_train_cv, y_test_cv = y_train_encoded[train_index], y_train_encoded[test_index]

    # Define your model (make sure it's the simplified version with regularization)
    model = create_simplified_model(input_dim=X_train_cv.shape[1])

    # Add early stopping and learning rate reduction as callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

    # Compile the model (ensure to add L2 regularization inside the create_model function)
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1,name='adam'), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Fit the model on the training split
    history = model.fit(
        X_train_cv, y_train_cv,
        validation_split=0.2,  # Further split training data into training/validation
        epochs=100,
        callbacks=[early_stopping, reduce_lr],
        batch_size=64,
        verbose=0  # Turn off verbose output to prevent clutter
    )

    # Evaluate the model on the test split
    test_loss, test_accuracy = model.evaluate(X_test_cv, y_test_cv, verbose=0)

    # Store the accuracy score
    accuracy_scores.append(test_accuracy)

# After cross-validation, calculate the average accuracy
average_accuracy = np.mean(accuracy_scores)

# %%
# Combine train and test data for final training
y_combined = np.hstack((y_train_encoded))
X_combined = preprocessor.fit_transform(X)

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Retrain the model on the combines data
final_model = create_simplified_model(X_combined.shape[1])


final_model.fit(
    X_combined,y_combined,
    epochs=100,
    callbacks=[early_stopping, reduce_lr],
    batch_size=64)
# Out:
# Epoch 1/100
# 24/36 [===================>..........] - ETA: 0s - loss: 5.1397 - accuracy: 0.3236WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 1s 4ms/step - loss: 4.8681 - accuracy: 0.3830 - lr: 0.1000
# Epoch 2/100
# 28/36 [======================>.......] - ETA: 0s - loss: 3.9380 - accuracy: 0.5804WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 3.8744 - accuracy: 0.5848 - lr: 0.1000
# Epoch 3/100
# 27/36 [=====================>........] - ETA: 0s - loss: 3.4208 - accuracy: 0.6354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 3.3781 - accuracy: 0.6313 - lr: 0.1000
# Epoch 4/100
# 26/36 [====================>.........] - ETA: 0s - loss: 3.0336 - accuracy: 0.6623WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 2.9785 - accuracy: 0.6635 - lr: 0.1000
# Epoch 5/100
# 24/36 [===================>..........] - ETA: 0s - loss: 2.6838 - accuracy: 0.6738WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 2.6566 - accuracy: 0.6726 - lr: 0.1000
# Epoch 6/100
# 27/36 [=====================>........] - ETA: 0s - loss: 2.3948 - accuracy: 0.6916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 2.3532 - accuracy: 0.6996 - lr: 0.1000
# Epoch 7/100
# 26/36 [====================>.........] - ETA: 0s - loss: 2.1284 - accuracy: 0.7175WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1144 - accuracy: 0.7087 - lr: 0.1000
# Epoch 8/100
# 24/36 [===================>..........] - ETA: 0s - loss: 1.9311 - accuracy: 0.7122WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 1.8929 - accuracy: 0.7183 - lr: 0.1000
# Epoch 9/100
# 29/36 [=======================>......] - ETA: 0s - loss: 1.7233 - accuracy: 0.7392WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 1.7137 - accuracy: 0.7383 - lr: 0.1000
# Epoch 10/100
# 28/36 [======================>.......] - ETA: 0s - loss: 1.5470 - accuracy: 0.7690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 1.5473 - accuracy: 0.7565 - lr: 0.1000
# Epoch 11/100
# 30/36 [========================>.....] - ETA: 0s - loss: 1.4516 - accuracy: 0.7484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 1.4406 - accuracy: 0.7470 - lr: 0.1000
# Epoch 12/100
# 27/36 [=====================>........] - ETA: 0s - loss: 1.3408 - accuracy: 0.7471WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 1.3272 - accuracy: 0.7491 - lr: 0.1000
# Epoch 13/100
# 33/36 [==========================>...] - ETA: 0s - loss: 1.2199 - accuracy: 0.7566WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 3ms/step - loss: 1.2224 - accuracy: 0.7570 - lr: 0.1000
# Epoch 14/100
# 29/36 [=======================>......] - ETA: 0s - loss: 1.1407 - accuracy: 0.7732WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 1.1295 - accuracy: 0.7709 - lr: 0.1000
# Epoch 15/100
# 25/36 [===================>..........] - ETA: 0s - loss: 1.0754 - accuracy: 0.7694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 1.0587 - accuracy: 0.7735 - lr: 0.1000
# Epoch 16/100
# 35/36 [============================>.] - ETA: 0s - loss: 1.0180 - accuracy: 0.7705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 1.0160 - accuracy: 0.7709 - lr: 0.1000
# Epoch 17/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.9622 - accuracy: 0.7772WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9666 - accuracy: 0.7739 - lr: 0.1000
# Epoch 18/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.9201 - accuracy: 0.7587WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9094 - accuracy: 0.7639 - lr: 0.1000
# Epoch 19/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.9080 - accuracy: 0.7686WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9029 - accuracy: 0.7735 - lr: 0.1000
# Epoch 20/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.8371 - accuracy: 0.7859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8349 - accuracy: 0.7865 - lr: 0.1000
# Epoch 21/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.8537 - accuracy: 0.7680WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8354 - accuracy: 0.7787 - lr: 0.1000
# Epoch 22/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.7973 - accuracy: 0.7903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7915 - accuracy: 0.7935 - lr: 0.1000
# Epoch 23/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.7909 - accuracy: 0.7870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7790 - accuracy: 0.7930 - lr: 0.1000
# Epoch 24/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.7472 - accuracy: 0.7933WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7537 - accuracy: 0.7887 - lr: 0.1000
# Epoch 25/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.7902 - accuracy: 0.7650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7820 - accuracy: 0.7717 - lr: 0.1000
# Epoch 26/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6858 - accuracy: 0.8177WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6960 - accuracy: 0.8139 - lr: 0.1000
# Epoch 27/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.7980WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7121 - accuracy: 0.7965 - lr: 0.1000
# Epoch 28/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.7107 - accuracy: 0.7918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7193 - accuracy: 0.7891 - lr: 0.1000
# Epoch 29/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6981 - accuracy: 0.7958WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.7922 - lr: 0.1000
# Epoch 30/100
# 33/36 [==========================>...] - ETA: 0s - loss: 0.7066 - accuracy: 0.7950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 3ms/step - loss: 0.7102 - accuracy: 0.7930 - lr: 0.1000
# Epoch 31/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6872 - accuracy: 0.8085WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.8070 - lr: 0.1000
# Epoch 32/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6745 - accuracy: 0.8075WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.8035 - lr: 0.1000
# Epoch 33/100
# 23/36 [==================>...........] - ETA: 0s - loss: 0.6413 - accuracy: 0.8084WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6710 - accuracy: 0.8035 - lr: 0.1000
# Epoch 34/100
# 24/36 [===================>..........] - ETA: 0s - loss: 0.6662 - accuracy: 0.7982WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6845 - accuracy: 0.7900 - lr: 0.1000
# Epoch 35/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.6783 - accuracy: 0.8050WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6760 - accuracy: 0.8096 - lr: 0.1000
# Epoch 36/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6731 - accuracy: 0.8155WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6662 - accuracy: 0.8152 - lr: 0.1000
# Epoch 37/100
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6350 - accuracy: 0.8163WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6419 - accuracy: 0.8143 - lr: 0.1000
# Epoch 38/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6409 - accuracy: 0.8192WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6426 - accuracy: 0.8178 - lr: 0.1000
# Epoch 39/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6552 - accuracy: 0.8193WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6733 - accuracy: 0.8109 - lr: 0.1000
# Epoch 40/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6831 - accuracy: 0.8006WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6763 - accuracy: 0.8061 - lr: 0.1000
# Epoch 41/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6872 - accuracy: 0.7980WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6770 - accuracy: 0.8013 - lr: 0.1000
# Epoch 42/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6321 - accuracy: 0.8198WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6567 - accuracy: 0.8113 - lr: 0.1000
# Epoch 43/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6621 - accuracy: 0.8044WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6618 - accuracy: 0.8022 - lr: 0.1000
# Epoch 44/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6902 - accuracy: 0.7839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.7935 - lr: 0.1000
# Epoch 45/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6274 - accuracy: 0.8149WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6269 - accuracy: 0.8161 - lr: 0.1000
# Epoch 46/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6568 - accuracy: 0.8130WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6683 - accuracy: 0.8070 - lr: 0.1000
# Epoch 47/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6408 - accuracy: 0.8227WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6513 - accuracy: 0.8161 - lr: 0.1000
# Epoch 48/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6510 - accuracy: 0.8214WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6329 - accuracy: 0.8304 - lr: 0.1000
# Epoch 49/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6685 - accuracy: 0.8025WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6594 - accuracy: 0.8078 - lr: 0.1000
# Epoch 50/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6203 - accuracy: 0.8224WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6283 - accuracy: 0.8196 - lr: 0.1000
# Epoch 51/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6478 - accuracy: 0.8082WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6586 - accuracy: 0.8078 - lr: 0.1000
# Epoch 52/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.6808 - accuracy: 0.7888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6712 - accuracy: 0.7974 - lr: 0.1000
# Epoch 53/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6498 - accuracy: 0.8167WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6448 - accuracy: 0.8196 - lr: 0.1000
# Epoch 54/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6292 - accuracy: 0.8335WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6418 - accuracy: 0.8204 - lr: 0.1000
# Epoch 55/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6257 - accuracy: 0.8343WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6373 - accuracy: 0.8287 - lr: 0.1000
# Epoch 56/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6513 - accuracy: 0.8120WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6486 - accuracy: 0.8161 - lr: 0.1000
# Epoch 57/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6560 - accuracy: 0.8161WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6613 - accuracy: 0.8143 - lr: 0.1000
# Epoch 58/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6400 - accuracy: 0.8228WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6471 - accuracy: 0.8178 - lr: 0.1000
# Epoch 59/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6589 - accuracy: 0.8161WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6750 - accuracy: 0.8096 - lr: 0.1000
# Epoch 60/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6196 - accuracy: 0.8352WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6234 - accuracy: 0.8283 - lr: 0.1000
# Epoch 61/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6462 - accuracy: 0.8201WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.8191 - lr: 0.1000
# Epoch 62/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6531 - accuracy: 0.8221WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6675 - accuracy: 0.8152 - lr: 0.1000
# Epoch 63/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6368 - accuracy: 0.8214WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6423 - accuracy: 0.8217 - lr: 0.1000
# Epoch 64/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6517 - accuracy: 0.8203WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6533 - accuracy: 0.8226 - lr: 0.1000
# Epoch 65/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6176 - accuracy: 0.8354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6311 - accuracy: 0.8313 - lr: 0.1000
# Epoch 66/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6469 - accuracy: 0.8195WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6584 - accuracy: 0.8152 - lr: 0.1000
# Epoch 67/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6401 - accuracy: 0.8275WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6428 - accuracy: 0.8278 - lr: 0.1000
# Epoch 68/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6484 - accuracy: 0.8113WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6459 - accuracy: 0.8083 - lr: 0.1000
# Epoch 69/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6652 - accuracy: 0.8225WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6681 - accuracy: 0.8217 - lr: 0.1000
# Epoch 70/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6346 - accuracy: 0.8337WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6383 - accuracy: 0.8317 - lr: 0.1000
# Epoch 71/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6438 - accuracy: 0.8251WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6501 - accuracy: 0.8217 - lr: 0.1000
# Epoch 72/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6601 - accuracy: 0.8165WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6707 - accuracy: 0.8157 - lr: 0.1000
# Epoch 73/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6212 - accuracy: 0.8367WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6279 - accuracy: 0.8378 - lr: 0.1000
# Epoch 74/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6414 - accuracy: 0.8152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6547 - accuracy: 0.8152 - lr: 0.1000
# Epoch 75/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.5708 - accuracy: 0.8617WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.8413 - lr: 0.1000
# Epoch 76/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6196 - accuracy: 0.8443WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6309 - accuracy: 0.8396 - lr: 0.1000
# Epoch 77/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6194 - accuracy: 0.8384WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6330 - accuracy: 0.8352 - lr: 0.1000
# Epoch 78/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6539 - accuracy: 0.8208WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6366 - accuracy: 0.8278 - lr: 0.1000
# Epoch 79/100
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6362 - accuracy: 0.8295WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6551 - accuracy: 0.8200 - lr: 0.1000
# Epoch 80/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6557 - accuracy: 0.8313WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6557 - accuracy: 0.8291 - lr: 0.1000
# Epoch 81/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6247 - accuracy: 0.8421WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6307 - accuracy: 0.8404 - lr: 0.1000
# Epoch 82/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6701 - accuracy: 0.8146WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6759 - accuracy: 0.8165 - lr: 0.1000
# Epoch 83/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6852 - accuracy: 0.8185WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6845 - accuracy: 0.8200 - lr: 0.1000
# Epoch 84/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6439 - accuracy: 0.8252WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6424 - accuracy: 0.8261 - lr: 0.1000
# Epoch 85/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6579 - accuracy: 0.8231WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6599 - accuracy: 0.8230 - lr: 0.1000
# Epoch 86/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6109 - accuracy: 0.8438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6059 - accuracy: 0.8461 - lr: 0.1000
# Epoch 87/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6450 - accuracy: 0.8221WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6617 - accuracy: 0.8143 - lr: 0.1000
# Epoch 88/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6217 - accuracy: 0.8377WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6372 - accuracy: 0.8326 - lr: 0.1000
# Epoch 89/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6103 - accuracy: 0.8417WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6272 - accuracy: 0.8322 - lr: 0.1000
# Epoch 90/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6612 - accuracy: 0.8292WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6555 - accuracy: 0.8300 - lr: 0.1000
# Epoch 91/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6659 - accuracy: 0.8193WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6700 - accuracy: 0.8130 - lr: 0.1000
# Epoch 92/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6233 - accuracy: 0.8448WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.8387 - lr: 0.1000
# Epoch 93/100
# 27/36 [=====================>........] - ETA: 0s - loss: 0.6525 - accuracy: 0.8229WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6671 - accuracy: 0.8148 - lr: 0.1000
# Epoch 94/100
# 28/36 [======================>.......] - ETA: 0s - loss: 0.6606 - accuracy: 0.8304WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6619 - accuracy: 0.8322 - lr: 0.1000
# Epoch 95/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6056 - accuracy: 0.8477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 3ms/step - loss: 0.6087 - accuracy: 0.8483 - lr: 0.1000
# Epoch 96/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6354 - accuracy: 0.8364WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6338 - accuracy: 0.8357 - lr: 0.1000
# Epoch 97/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6450 - accuracy: 0.8394WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6506 - accuracy: 0.8370 - lr: 0.1000
# Epoch 98/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6631 - accuracy: 0.8236WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6676 - accuracy: 0.8226 - lr: 0.1000
# Epoch 99/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6573 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6661 - accuracy: 0.8213 - lr: 0.1000
# Epoch 100/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6213 - accuracy: 0.8427WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6453 - accuracy: 0.8343 - lr: 0.1000

# %%
final_model.save('final_model.h5')
import pickle
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)
with open('preprocessor.pkl', 'wb') as f:
    pickle.dump(preprocessor, f)
with open('accuracy.pkl', 'wb') as f:
    pickle.dump(average_accuracy, f)
