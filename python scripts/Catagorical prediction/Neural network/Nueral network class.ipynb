# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import joblib
from sklearn.datasets import make_classification
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV, cross_val_score,TimeSeriesSplit
from sklearn.pipeline import Pipeline
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
from scipy.stats import uniform, randint
from sklearn.compose import ColumnTransformer
import os

# %%
# Load the dataset
os.chdir('C:\\Users\\blake\\Desktop\\AFL Odds\\cleaned data')
match_results = pd.read_csv('afl_match_results_cleaned.csv')
os.chdir('C:\\Users\\blake\\Desktop\\AFL Odds\\python scripts\\Catagorical prediction\\Neural network')

# Define the features and the target variable
weather_dummies = pd.get_dummies(match_results['weather.weatherType'])
X = match_results.drop(columns=['match.homeTeam.name', 'match.awayTeam.name','venue.name','Margin','Result','weather.weatherType']).astype('float64')  # Drop irrelevant columns
X = pd.concat([X, weather_dummies], axis=1)
y = match_results['Result']  # BW, LW, D, LL, BL

# Assuming 'weather_columns' is a list of your dummy weather variables
weather_columns = weather_dummies.columns  # Replace with actual weather columns
discrete_columns = ['Home.Team.Venue.Win.Streak', 'Away.Team.Venue.Win.Streak','Home.Win.Streak'] 
continuous_columns = [col for col in X.columns if col not in weather_columns and col not in discrete_columns]

# ColumnTransformer to apply StandardScaler only to continuous features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), continuous_columns),
        ('disc', MinMaxScaler(), discrete_columns),
        ('weather', 'passthrough', weather_columns)  # Weather columns are passed through unchanged
    ]
)

# Initialize LabelEncoder
encoder = LabelEncoder()

# Fit and transform the target variable
y_encoded = encoder.fit_transform(y)

cutoff_index = int(0.8 * len(match_results))

# Create the training set (first 80%) and validation set (last 20%)
X_train = X
y_train = y

y_train_encoded = encoder.fit_transform(y_train)

# Standardize the features
X_train = preprocessor.fit_transform(X_train)

# %% [markdown]
# ### Run at beginning of season

# %%
# # Function to create the Keras model
# def create_model(optimizer='adam', dropout_rate=0.3, neurons=64, learn_rate=0.01):
#     model = Sequential([
#         Dense(neurons, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.001), input_dim=X_train.shape[1]),
#         BatchNormalization(),
#         Dropout(dropout_rate),
#         Dense(32, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.001)),
#         BatchNormalization(),
#         Dropout(dropout_rate),
#         Dense(16, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
#         BatchNormalization(),
#         Dropout(dropout_rate),
#         Dense(5, kernel_initializer='he_uniform', activation='softmax')
#     ])
#     model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learn_rate, name=optimizer), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return model


# # Create the KerasClassifier wrapper
# model = KerasClassifier(build_fn=create_model, verbose=0)

# # Define the grid of hyperparameters to search
# param_grid = {
#     'batch_size': [32, 64, 128],
#     'epochs': [20, 30, 50],
#     'optimizer': ['adam', 'sgd'],
#     'dropout_rate': [0.2, 0.3, 0.5],
#     'neurons': [32, 64, 128],
#     'learn_rate': [0.001, 0.01, 0.1]
# }

# # Use KFold cross-validation
# kfold = KFold(n_splits=3, shuffle=True, random_state=42)

# # Initialize GridSearchCV
# grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# # Fit the model using GridSearchCV
# grid_result = grid.fit(X_train, y_train)

# # Summarize results
# print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")

# # Evaluate on the test set
# best_model = grid_result.best_estimator_.model
# test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
# print(f"Test Accuracy: {test_accuracy:.4f}")

# %% [markdown]
# ### Continue programming

# %%
# Define artificial neural network
def create_simplified_model(input_dim):
    model = Sequential([
        Dense(128, kernel_initializer='he_uniform', activation='relu', input_dim=input_dim, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(16, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(5, kernel_initializer='he_uniform', activation='softmax')
    ])
    
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1,name='adam'), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Define TimeSeriesSplit with the desired number of splits
n_splits = 5  # You can adjust the number of splits
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize a list to store accuracies from each fold
accuracy_scores = []

# Perform time-aware cross-validation
for train_index, test_index in tscv.split(X_train):
    # Split the data into training and validation sets based on the time split
    X_train_cv, X_test_cv = X_train[train_index], X_train[test_index]
    y_train_cv, y_test_cv = y_train_encoded[train_index], y_train_encoded[test_index]

    # Define your model (make sure it's the simplified version with regularization)
    model = create_simplified_model(input_dim=X_train_cv.shape[1])

    # Add early stopping and learning rate reduction as callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

    # Compile the model (ensure to add L2 regularization inside the create_model function)
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1,name='adam'), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Fit the model on the training split
    history = model.fit(
        X_train_cv, y_train_cv,
        validation_split=0.2,  # Further split training data into training/validation
        epochs=100,
        callbacks=[early_stopping, reduce_lr],
        batch_size=64,
        verbose=0  # Turn off verbose output to prevent clutter
    )

    # Evaluate the model on the test split
    test_loss, test_accuracy = model.evaluate(X_test_cv, y_test_cv, verbose=0)

    # Store the accuracy score
    accuracy_scores.append(test_accuracy)

# After cross-validation, calculate the average accuracy
average_accuracy = np.mean(accuracy_scores)

# %%
# Combine train and test data for final training
y_combined = np.hstack((y_train_encoded))
X_combined = preprocessor.fit_transform(X)

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Retrain the model on the combines data
final_model = create_simplified_model(X_combined.shape[1])


final_model.fit(
    X_combined,y_combined,
    epochs=100,
    callbacks=[early_stopping, reduce_lr],
    batch_size=64)
# Out:
# Epoch 1/100
# 28/38 [=====================>........] - ETA: 0s - loss: 4.9690 - accuracy: 0.3672WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 2s 4ms/step - loss: 4.8003 - accuracy: 0.3940 - lr: 0.1000
# Epoch 2/100
# 29/38 [=====================>........] - ETA: 0s - loss: 3.9163 - accuracy: 0.5474WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 3.8666 - accuracy: 0.5489 - lr: 0.1000
# Epoch 3/100
# 29/38 [=====================>........] - ETA: 0s - loss: 3.3900 - accuracy: 0.6094WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 3.3419 - accuracy: 0.6118 - lr: 0.1000
# Epoch 4/100
# 29/38 [=====================>........] - ETA: 0s - loss: 2.9794 - accuracy: 0.6428WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 2.9392 - accuracy: 0.6476 - lr: 0.1000
# Epoch 5/100
# 30/38 [======================>.......] - ETA: 0s - loss: 2.6068 - accuracy: 0.6802WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 2.5783 - accuracy: 0.6814 - lr: 0.1000
# Epoch 6/100
# 29/38 [=====================>........] - ETA: 0s - loss: 2.3193 - accuracy: 0.6902WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 2.2923 - accuracy: 0.6918 - lr: 0.1000
# Epoch 7/100
# 30/38 [======================>.......] - ETA: 0s - loss: 2.0618 - accuracy: 0.7125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 2.0501 - accuracy: 0.7105 - lr: 0.1000
# Epoch 8/100
# 30/38 [======================>.......] - ETA: 0s - loss: 1.8495 - accuracy: 0.7151WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.8316 - accuracy: 0.7135 - lr: 0.1000
# Epoch 9/100
# 30/38 [======================>.......] - ETA: 0s - loss: 1.6600 - accuracy: 0.7437WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.6483 - accuracy: 0.7368 - lr: 0.1000
# Epoch 10/100
# 30/38 [======================>.......] - ETA: 0s - loss: 1.4927 - accuracy: 0.7557WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.4902 - accuracy: 0.7480 - lr: 0.1000
# Epoch 11/100
# 31/38 [=======================>......] - ETA: 0s - loss: 1.3817 - accuracy: 0.7500WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.3749 - accuracy: 0.7472 - lr: 0.1000
# Epoch 12/100
# 29/38 [=====================>........] - ETA: 0s - loss: 1.2756 - accuracy: 0.7656WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.2674 - accuracy: 0.7576 - lr: 0.1000
# Epoch 13/100
# 30/38 [======================>.......] - ETA: 0s - loss: 1.1606 - accuracy: 0.7688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.1522 - accuracy: 0.7709 - lr: 0.1000
# Epoch 14/100
# 31/38 [=======================>......] - ETA: 0s - loss: 1.0942 - accuracy: 0.7742WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0832 - accuracy: 0.7772 - lr: 0.1000
# Epoch 15/100
# 30/38 [======================>.......] - ETA: 0s - loss: 1.0586 - accuracy: 0.7458WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 1.0582 - accuracy: 0.7418 - lr: 0.1000
# Epoch 16/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.9615 - accuracy: 0.7896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9522 - accuracy: 0.7926 - lr: 0.1000
# Epoch 17/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.8996 - accuracy: 0.7829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.9014 - accuracy: 0.7805 - lr: 0.1000
# Epoch 18/100
# 32/38 [========================>.....] - ETA: 0s - loss: 0.8804 - accuracy: 0.7832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8846 - accuracy: 0.7793 - lr: 0.1000
# Epoch 19/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.8306 - accuracy: 0.7838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8368 - accuracy: 0.7776 - lr: 0.1000
# Epoch 20/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.7895 - accuracy: 0.8044WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.8202 - accuracy: 0.7955 - lr: 0.1000
# Epoch 21/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.7876 - accuracy: 0.7974WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7916 - accuracy: 0.7918 - lr: 0.1000
# Epoch 22/100
# 33/38 [=========================>....] - ETA: 0s - loss: 0.7738 - accuracy: 0.7940WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7820 - accuracy: 0.7876 - lr: 0.1000
# Epoch 23/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.7505 - accuracy: 0.7913WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7556 - accuracy: 0.7868 - lr: 0.1000
# Epoch 24/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.7411 - accuracy: 0.7908WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7390 - accuracy: 0.7893 - lr: 0.1000
# Epoch 25/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.7431 - accuracy: 0.7852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7540 - accuracy: 0.7768 - lr: 0.1000
# Epoch 26/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.7035 - accuracy: 0.7949WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7235 - accuracy: 0.7859 - lr: 0.1000
# Epoch 27/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6760 - accuracy: 0.8095WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6937 - accuracy: 0.8026 - lr: 0.1000
# Epoch 28/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.7264 - accuracy: 0.7928WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7254 - accuracy: 0.7909 - lr: 0.1000
# Epoch 29/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6936 - accuracy: 0.7877WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.7909 - lr: 0.1000
# Epoch 30/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6895 - accuracy: 0.7958WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.8022 - lr: 0.1000
# Epoch 31/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.7167 - accuracy: 0.7772WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.7214 - accuracy: 0.7759 - lr: 0.1000
# Epoch 32/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6830 - accuracy: 0.7984WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.7943 - lr: 0.1000
# Epoch 33/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6761 - accuracy: 0.8049WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6818 - accuracy: 0.8017 - lr: 0.1000
# Epoch 34/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6520 - accuracy: 0.8098WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6365 - accuracy: 0.8159 - lr: 0.1000
# Epoch 35/100
# 26/38 [===================>..........] - ETA: 0s - loss: 0.6521 - accuracy: 0.8101WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6699 - accuracy: 0.8080 - lr: 0.1000
# Epoch 36/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6559 - accuracy: 0.8119WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6726 - accuracy: 0.8063 - lr: 0.1000
# Epoch 37/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6313 - accuracy: 0.8154WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6474 - accuracy: 0.8101 - lr: 0.1000
# Epoch 38/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.6873 - accuracy: 0.8052WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6908 - accuracy: 0.8001 - lr: 0.1000
# Epoch 39/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6457 - accuracy: 0.8168WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6612 - accuracy: 0.8117 - lr: 0.1000
# Epoch 40/100
# 35/38 [==========================>...] - ETA: 0s - loss: 0.6595 - accuracy: 0.8188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6616 - accuracy: 0.8172 - lr: 0.1000
# Epoch 41/100
# 36/38 [===========================>..] - ETA: 0s - loss: 0.6862 - accuracy: 0.8008WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6900 - accuracy: 0.7988 - lr: 0.1000
# Epoch 42/100
# 35/38 [==========================>...] - ETA: 0s - loss: 0.6602 - accuracy: 0.8089WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6572 - accuracy: 0.8088 - lr: 0.1000
# Epoch 43/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6510 - accuracy: 0.8180WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6510 - accuracy: 0.8180 - lr: 0.1000
# Epoch 44/100
# 36/38 [===========================>..] - ETA: 0s - loss: 0.6472 - accuracy: 0.8116WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6473 - accuracy: 0.8113 - lr: 0.1000
# Epoch 45/100
# 36/38 [===========================>..] - ETA: 0s - loss: 0.6855 - accuracy: 0.8016WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6838 - accuracy: 0.8026 - lr: 0.1000
# Epoch 46/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6531 - accuracy: 0.8154WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 6ms/step - loss: 0.6569 - accuracy: 0.8109 - lr: 0.1000
# Epoch 47/100
# 26/38 [===================>..........] - ETA: 0s - loss: 0.6344 - accuracy: 0.8269WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6393 - accuracy: 0.8247 - lr: 0.1000
# Epoch 48/100
# 36/38 [===========================>..] - ETA: 0s - loss: 0.6582 - accuracy: 0.8095WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6552 - accuracy: 0.8117 - lr: 0.1000
# Epoch 49/100
# 26/38 [===================>..........] - ETA: 0s - loss: 0.6663 - accuracy: 0.8167WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6682 - accuracy: 0.8101 - lr: 0.1000
# Epoch 50/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6541 - accuracy: 0.8200WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6674 - accuracy: 0.8180 - lr: 0.1000
# Epoch 51/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6703 - accuracy: 0.8147WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6761 - accuracy: 0.8147 - lr: 0.1000
# Epoch 52/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.6642 - accuracy: 0.8192WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6705 - accuracy: 0.8167 - lr: 0.1000
# Epoch 53/100
# 35/38 [==========================>...] - ETA: 0s - loss: 0.6515 - accuracy: 0.8246WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6504 - accuracy: 0.8238 - lr: 0.1000
# Epoch 54/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6302 - accuracy: 0.8344WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6469 - accuracy: 0.8276 - lr: 0.1000
# Epoch 55/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6702 - accuracy: 0.8231WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6548 - accuracy: 0.8280 - lr: 0.1000
# Epoch 56/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6416 - accuracy: 0.8191WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6420 - accuracy: 0.8209 - lr: 0.1000
# Epoch 57/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6252 - accuracy: 0.8271WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6495 - accuracy: 0.8147 - lr: 0.1000
# Epoch 58/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6370 - accuracy: 0.8229WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6718 - accuracy: 0.8076 - lr: 0.1000
# Epoch 59/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6418 - accuracy: 0.8227WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6438 - accuracy: 0.8251 - lr: 0.1000
# Epoch 60/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6459 - accuracy: 0.8316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6580 - accuracy: 0.8242 - lr: 0.1000
# Epoch 61/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6228 - accuracy: 0.8333WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6276 - accuracy: 0.8330 - lr: 0.1000
# Epoch 62/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.6686 - accuracy: 0.8092WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6732 - accuracy: 0.8130 - lr: 0.1000
# Epoch 63/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6695 - accuracy: 0.8114WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6566 - accuracy: 0.8122 - lr: 0.1000
# Epoch 64/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6310 - accuracy: 0.8382WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6356 - accuracy: 0.8347 - lr: 0.1000
# Epoch 65/100
# 36/38 [===========================>..] - ETA: 0s - loss: 0.6773 - accuracy: 0.8216WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6800 - accuracy: 0.8197 - lr: 0.1000
# Epoch 66/100
# 26/38 [===================>..........] - ETA: 0s - loss: 0.6694 - accuracy: 0.8239WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6799 - accuracy: 0.8167 - lr: 0.1000
# Epoch 67/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6580 - accuracy: 0.8177WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6599 - accuracy: 0.8167 - lr: 0.1000
# Epoch 68/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6570 - accuracy: 0.8154WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6557 - accuracy: 0.8188 - lr: 0.1000
# Epoch 69/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6611 - accuracy: 0.8167WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6611 - accuracy: 0.8167 - lr: 0.1000
# Epoch 70/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6023 - accuracy: 0.8420WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6240 - accuracy: 0.8355 - lr: 0.1000
# Epoch 71/100
# 35/38 [==========================>...] - ETA: 0s - loss: 0.6660 - accuracy: 0.8214WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6680 - accuracy: 0.8217 - lr: 0.1000
# Epoch 72/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6479 - accuracy: 0.8258WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6529 - accuracy: 0.8247 - lr: 0.1000
# Epoch 73/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6448 - accuracy: 0.8322WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6371 - accuracy: 0.8326 - lr: 0.1000
# Epoch 74/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6183 - accuracy: 0.8417WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6437 - accuracy: 0.8284 - lr: 0.1000
# Epoch 75/100
# 37/38 [============================>.] - ETA: 0s - loss: 0.6118 - accuracy: 0.8319WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 6ms/step - loss: 0.6094 - accuracy: 0.8330 - lr: 0.1000
# Epoch 76/100
# 32/38 [========================>.....] - ETA: 0s - loss: 0.6723 - accuracy: 0.8218WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6724 - accuracy: 0.8217 - lr: 0.1000
# Epoch 77/100
# 32/38 [========================>.....] - ETA: 0s - loss: 0.6423 - accuracy: 0.8311WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6446 - accuracy: 0.8292 - lr: 0.1000
# Epoch 78/100
# 37/38 [============================>.] - ETA: 0s - loss: 0.6775 - accuracy: 0.8041WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6775 - accuracy: 0.8051 - lr: 0.1000
# Epoch 79/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6452 - accuracy: 0.8316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6374 - accuracy: 0.8342 - lr: 0.1000
# Epoch 80/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6414 - accuracy: 0.8281WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6448 - accuracy: 0.8297 - lr: 0.1000
# Epoch 81/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6092 - accuracy: 0.8521WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6351 - accuracy: 0.8405 - lr: 0.1000
# Epoch 82/100
# 38/38 [==============================] - ETA: 0s - loss: 0.6657 - accuracy: 0.8084WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6657 - accuracy: 0.8084 - lr: 0.1000
# Epoch 83/100
# 36/38 [===========================>..] - ETA: 0s - loss: 0.6329 - accuracy: 0.8316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6311 - accuracy: 0.8326 - lr: 0.1000
# Epoch 84/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.6476 - accuracy: 0.8192WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6562 - accuracy: 0.8197 - lr: 0.1000
# Epoch 85/100
# 27/38 [====================>.........] - ETA: 0s - loss: 0.6621 - accuracy: 0.8345WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.8242 - lr: 0.1000
# Epoch 86/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6654 - accuracy: 0.8246WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6552 - accuracy: 0.8276 - lr: 0.1000
# Epoch 87/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6492 - accuracy: 0.8291WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6514 - accuracy: 0.8284 - lr: 0.1000
# Epoch 88/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.6897 - accuracy: 0.8119WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.8101 - lr: 0.1000
# Epoch 89/100
# 26/38 [===================>..........] - ETA: 0s - loss: 0.6122 - accuracy: 0.8371WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6399 - accuracy: 0.8288 - lr: 0.1000
# Epoch 90/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6667 - accuracy: 0.8227WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6624 - accuracy: 0.8251 - lr: 0.1000
# Epoch 91/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6416 - accuracy: 0.8302WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6575 - accuracy: 0.8234 - lr: 0.1000
# Epoch 92/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6559 - accuracy: 0.8182WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6587 - accuracy: 0.8184 - lr: 0.1000
# Epoch 93/100
# 28/38 [=====================>........] - ETA: 0s - loss: 0.6514 - accuracy: 0.8309WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6506 - accuracy: 0.8309 - lr: 0.1000
# Epoch 94/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6145 - accuracy: 0.8443WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6165 - accuracy: 0.8434 - lr: 0.1000
# Epoch 95/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6602 - accuracy: 0.8260WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6572 - accuracy: 0.8301 - lr: 0.1000
# Epoch 96/100
# 30/38 [======================>.......] - ETA: 0s - loss: 0.6373 - accuracy: 0.8260WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6294 - accuracy: 0.8313 - lr: 0.1000
# Epoch 97/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6180 - accuracy: 0.8478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6291 - accuracy: 0.8438 - lr: 0.1000
# Epoch 98/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6470 - accuracy: 0.8276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6488 - accuracy: 0.8297 - lr: 0.1000
# Epoch 99/100
# 31/38 [=======================>......] - ETA: 0s - loss: 0.6500 - accuracy: 0.8367WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6451 - accuracy: 0.8392 - lr: 0.1000
# Epoch 100/100
# 29/38 [=====================>........] - ETA: 0s - loss: 0.6297 - accuracy: 0.8330WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.8347 - lr: 0.1000

# %%
final_model.save('final_model.h5')
import pickle
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)
with open('preprocessor.pkl', 'wb') as f:
    pickle.dump(preprocessor, f)
with open('accuracy.pkl', 'wb') as f:
    pickle.dump(average_accuracy, f)
