# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import joblib
from sklearn.datasets import make_classification
from sklearn.model_selection import GridSearchCV, KFold, RandomizedSearchCV, cross_val_score,TimeSeriesSplit
from sklearn.pipeline import Pipeline
from tensorflow.keras.regularizers import l2
from sklearn.utils.class_weight import compute_class_weight
from scipy.stats import uniform, randint
from sklearn.compose import ColumnTransformer

# %%
# Load the dataset
match_results = pd.read_csv('afl_match_results_cleaned.csv')

# Define the features and the target variable
weather_dummies = pd.get_dummies(match_results['weather.weatherType'])
X = match_results.drop(columns=['match.homeTeam.name', 'match.awayTeam.name','venue.name','Margin','Result','weather.weatherType']).astype('float64')  # Drop irrelevant columns
X = pd.concat([X, weather_dummies], axis=1)
y = match_results['Result']  # BW, LW, D, LL, BL

# Assuming 'weather_columns' is a list of your dummy weather variables
weather_columns = weather_dummies.columns  # Replace with actual weather columns
discrete_columns = ['Home.Team.Venue.Win.Streak', 'Away.Team.Venue.Win.Streak','Home.Win.Streak'] 
continuous_columns = [col for col in X.columns if col not in weather_columns and col not in discrete_columns]

# ColumnTransformer to apply StandardScaler only to continuous features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), continuous_columns),
        ('disc', MinMaxScaler(), discrete_columns),
        ('weather', 'passthrough', weather_columns)  # Weather columns are passed through unchanged
    ]
)

# Initialize LabelEncoder
encoder = LabelEncoder()

# Fit and transform the target variable
y_encoded = encoder.fit_transform(y)

cutoff_index = int(0.8 * len(match_results))

# Create the training set (first 80%) and validation set (last 20%)
X_train = X
y_train = y

y_train_encoded = encoder.fit_transform(y_train)

# Standardize the features
X_train = preprocessor.fit_transform(X_train)

# %% [markdown]
# ### Run at beginning of season

# %%
# Function to create the Keras model
def create_model(optimizer='adam', dropout_rate=0.3, neurons=64, learn_rate=0.01):
    model = Sequential([
        Dense(neurons, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.001), input_dim=X_train.shape[1]),
        BatchNormalization(),
        Dropout(dropout_rate),
        Dense(32, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.001)),
        BatchNormalization(),
        Dropout(dropout_rate),
        Dense(16, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(dropout_rate),
        Dense(5, kernel_initializer='he_uniform', activation='softmax')
    ])
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learn_rate, name=optimizer), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


# Create the KerasClassifier wrapper
model = KerasClassifier(build_fn=create_model, verbose=0)

# Define the grid of hyperparameters to search
param_grid = {
    'batch_size': [32, 64, 128],
    'epochs': [20, 30, 50],
    'optimizer': ['adam', 'sgd'],
    'dropout_rate': [0.2, 0.3, 0.5],
    'neurons': [32, 64, 128],
    'learn_rate': [0.001, 0.01, 0.1]
}

# Use KFold cross-validation
kfold = KFold(n_splits=3, shuffle=True, random_state=42)

# Initialize GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# Fit the model using GridSearchCV
grid_result = grid.fit(X_train, y_train)

# Summarize results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")

# Evaluate on the test set
best_model = grid_result.best_estimator_.model
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# C:\Users\blake\AppData\Local\Temp\ipykernel_32820\2422393947.py:20: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, verbose=0)
# Best: 0.7580301364262899 using {'batch_size': 64, 'dropout_rate': 0.3, 'epochs': 50, 'learn_rate': 0.1, 'neurons': 128, 'optimizer': 'adam'}
# 17/17 [==============================] - 0s 4ms/step - loss: 0.7642 - accuracy: 0.7816
# Test Accuracy: 78.16%

# %% [markdown]
# ### Continue programming

# %%
# Define artificial neural network
def create_simplified_model(input_dim):
    model = Sequential([
        Dense(128, kernel_initializer='he_uniform', activation='relu', input_dim=input_dim, kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(32, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(16, kernel_initializer='he_uniform', activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(5, kernel_initializer='he_uniform', activation='softmax')
    ])
    
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1,name='adam'), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Define TimeSeriesSplit with the desired number of splits
n_splits = 5  # You can adjust the number of splits
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize a list to store accuracies from each fold
accuracy_scores = []

# Perform time-aware cross-validation
for train_index, test_index in tscv.split(X_train):
    # Split the data into training and validation sets based on the time split
    X_train_cv, X_test_cv = X_train[train_index], X_train[test_index]
    y_train_cv, y_test_cv = y_train_encoded[train_index], y_train_encoded[test_index]

    # Define your model (make sure it's the simplified version with regularization)
    model = create_simplified_model(input_dim=X_train_cv.shape[1])

    # Add early stopping and learning rate reduction as callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

    # Compile the model (ensure to add L2 regularization inside the create_model function)
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1,name='adam'), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Fit the model on the training split
    history = model.fit(
        X_train_cv, y_train_cv,
        validation_split=0.2,  # Further split training data into training/validation
        epochs=100,
        callbacks=[early_stopping, reduce_lr],
        batch_size=64,
        verbose=0  # Turn off verbose output to prevent clutter
    )

    # Evaluate the model on the test split
    test_loss, test_accuracy = model.evaluate(X_test_cv, y_test_cv, verbose=0)

    # Store the accuracy score
    accuracy_scores.append(test_accuracy)

# After cross-validation, calculate the average accuracy
average_accuracy = np.mean(accuracy_scores)
print(f'Average Accuracy from TimeSeriesSplit CV: {average_accuracy * 100:.2f}%')
# Out:
# Average Accuracy from TimeSeriesSplit CV: 72.25%

# %%
# Combine train and test data for final training
y_combined = np.hstack((y_train_encoded))

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Retrain the model on the combines data
final_model = create_simplified_model(input_dim)

X_combined = preprocessor.fit_transform(X)

final_model.fit(
    X_combined,y_combined,
    epochs=100,
    callbacks=[early_stopping, reduce_lr],
    batch_size=64)
# Out:
# Epoch 1/100
# 33/36 [==========================>...] - ETA: 0s - loss: 5.0103 - accuracy: 0.3750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 2s 5ms/step - loss: 4.9596 - accuracy: 0.3849 - lr: 0.1000
# Epoch 2/100
# 27/36 [=====================>........] - ETA: 0s - loss: 4.0644 - accuracy: 0.5243WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 6ms/step - loss: 3.9972 - accuracy: 0.5262 - lr: 0.1000
# Epoch 3/100
# 33/36 [==========================>...] - ETA: 0s - loss: 3.4631 - accuracy: 0.6127WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 3.4432 - accuracy: 0.6129 - lr: 0.1000
# Epoch 4/100
# 32/36 [=========================>....] - ETA: 0s - loss: 3.0666 - accuracy: 0.6284WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 3.0544 - accuracy: 0.6286 - lr: 0.1000
# Epoch 5/100
# 34/36 [===========================>..] - ETA: 0s - loss: 2.6846 - accuracy: 0.6820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 2.6703 - accuracy: 0.6840 - lr: 0.1000
# Epoch 6/100
# 35/36 [============================>.] - ETA: 0s - loss: 2.3859 - accuracy: 0.6987WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 2.3835 - accuracy: 0.6988 - lr: 0.1000
# Epoch 7/100
# 34/36 [===========================>..] - ETA: 0s - loss: 2.1437 - accuracy: 0.7027WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 2.1443 - accuracy: 0.7018 - lr: 0.1000
# Epoch 8/100
# 33/36 [==========================>...] - ETA: 0s - loss: 1.9201 - accuracy: 0.7225WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 1.9166 - accuracy: 0.7184 - lr: 0.1000
# Epoch 9/100
# 31/36 [========================>.....] - ETA: 0s - loss: 1.7420 - accuracy: 0.7409WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 1
ARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.7977 - lr: 0.1000
# Epoch 38/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6364 - accuracy: 0.8211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 6ms/step - loss: 0.6561 - accuracy: 0.8104 - lr: 0.1000
# Epoch 39/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6677 - accuracy: 0.8099WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6756 - accuracy: 0.8073 - lr: 0.1000
# Epoch 40/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6515 - accuracy: 0.8120WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6548 - accuracy: 0.8086 - lr: 0.1000
# Epoch 41/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6634 - accuracy: 0.8145WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.8056 - lr: 0.1000
# Epoch 42/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6175 - accuracy: 0.8306WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6342 - accuracy: 0.8252 - lr: 0.1000
# Epoch 43/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6690 - accuracy: 0.8042WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.8017 - lr: 0.1000
# Epoch 44/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6457 - accuracy: 0.8159WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6465 - accuracy: 0.8178 - lr: 0.1000
# Epoch 45/100
# 31/36 [========================>.....] - ETA: 0s - loss: 0.6718 - accuracy: 0.8120WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6674 - accuracy: 0.8126 - lr: 0.1000
# Epoch 46/100
# 33/36 [==========================>...] - ETA: 0s - loss: 0.6515 - accuracy: 0.8134WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.8099 - lr: 0.1000
# Epoch 47/100
# 30/36 [========================>.....] - ETA: 0s - loss: 0.6603 - accuracy: 0.8156WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 6ms/step - loss: 0.6728 - accuracy: 0.8117 - lr: 0.1000
# Epoch 48/100
# 32/36 [=========================>....] - ETA: 0s - loss: 0.6302 - accuracy: 0.8354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6355 - accuracy: 0.8326 - lr: 0.1000
# Epoch 49/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6407 - accuracy: 0.8330WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 6ms/step - loss: 0.6333 - accuracy: 0.8344 - lr: 0.1000
# Epoch 50/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6616 - accuracy: 0.8166WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6640 - accuracy: 0.8165 - lr: 0.1000
# Epoch 51/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.8065WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6802 - accuracy: 0.8065 - lr: 0.1000
# Epoch 52/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6899 - accuracy: 0.8051WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6854 - accuracy: 0.8051 - lr: 0.1000
# Epoch 53/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6466 - accuracy: 0.8174WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6514 - accuracy: 0.8139 - lr: 0.1000
# Epoch 54/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6340 - accuracy: 0.8355WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6420 - accuracy: 0.8309 - lr: 0.1000
# Epoch 55/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6347 - accuracy: 0.8208WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6436 - accuracy: 0.8156 - lr: 0.1000
# Epoch 56/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.8235WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6553 - accuracy: 0.8235 - lr: 0.1000
# Epoch 57/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6135 - accuracy: 0.8346WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6156 - accuracy: 0.8352 - lr: 0.1000
# Epoch 58/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6900 - accuracy: 0.8037WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6976 - accuracy: 0.8047 - lr: 0.1000
# Epoch 59/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6598 - accuracy: 0.8134WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.8126 - lr: 0.1000
# Epoch 60/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.8182WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6618 - accuracy: 0.8182 - lr: 0.1000
# Epoch 61/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6631 - accuracy: 0.8175WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6674 - accuracy: 0.8143 - lr: 0.1000
# Epoch 62/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6627 - accuracy: 0.8100WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6638 - accuracy: 0.8108 - lr: 0.1000
# Epoch 63/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.8309WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6354 - accuracy: 0.8309 - lr: 0.1000
# Epoch 64/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6557 - accuracy: 0.8194WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6451 - accuracy: 0.8296 - lr: 0.1000
# Epoch 65/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6056 - accuracy: 0.8400WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6156 - accuracy: 0.8339 - lr: 0.1000
# Epoch 66/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6652 - accuracy: 0.8139WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6652 - accuracy: 0.8139 - lr: 0.1000
# Epoch 67/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6258 - accuracy: 0.8433WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6268 - accuracy: 0.8418 - lr: 0.1000
# Epoch 68/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6949 - accuracy: 0.8157WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6953 - accuracy: 0.8156 - lr: 0.1000
# Epoch 69/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6631 - accuracy: 0.8182WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6631 - accuracy: 0.8182 - lr: 0.1000
# Epoch 70/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6373 - accuracy: 0.8317WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6351 - accuracy: 0.8322 - lr: 0.1000
# Epoch 71/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6183 - accuracy: 0.8405WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6177 - accuracy: 0.8396 - lr: 0.1000
# Epoch 72/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.8034WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.8034 - lr: 0.1000
# Epoch 73/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6491 - accuracy: 0.8188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.8200 - lr: 0.1000
# Epoch 74/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6419 - accuracy: 0.8290WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6530 - accuracy: 0.8256 - lr: 0.1000
# Epoch 75/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6146 - accuracy: 0.8425WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.8365 - lr: 0.1000
# Epoch 76/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6411 - accuracy: 0.8251WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6390 - accuracy: 0.8278 - lr: 0.1000
# Epoch 77/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6270 - accuracy: 0.8319WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.8348 - lr: 0.1000
# Epoch 78/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6574 - accuracy: 0.8125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6387 - accuracy: 0.8235 - lr: 0.1000
# Epoch 79/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6564 - accuracy: 0.8263WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6457 - accuracy: 0.8339 - lr: 0.1000
# Epoch 80/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6543 - accuracy: 0.8212WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6531 - accuracy: 0.8213 - lr: 0.1000
# Epoch 81/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6589 - accuracy: 0.8254WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6576 - accuracy: 0.8265 - lr: 0.1000
# Epoch 82/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6585 - accuracy: 0.8228WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6584 - accuracy: 0.8230 - lr: 0.1000
# Epoch 83/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6791 - accuracy: 0.8170WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6803 - accuracy: 0.8169 - lr: 0.1000
# Epoch 84/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6455 - accuracy: 0.8294WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6440 - accuracy: 0.8291 - lr: 0.1000
# Epoch 85/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6515 - accuracy: 0.8188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6677 - accuracy: 0.8099 - lr: 0.1000
# Epoch 86/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6104 - accuracy: 0.8512WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6302 - accuracy: 0.8378 - lr: 0.1000
# Epoch 87/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.6362 - accuracy: 0.8272WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6346 - accuracy: 0.8274 - lr: 0.1000
# Epoch 88/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6424 - accuracy: 0.8341WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6527 - accuracy: 0.8322 - lr: 0.1000
# Epoch 89/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6327 - accuracy: 0.8365WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6436 - accuracy: 0.8274 - lr: 0.1000
# Epoch 90/100
# 24/36 [===================>..........] - ETA: 0s - loss: 0.5840 - accuracy: 0.8529WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6164 - accuracy: 0.8352 - lr: 0.1000
# Epoch 91/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.7260 - accuracy: 0.8065WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7264 - accuracy: 0.8043 - lr: 0.1000
# Epoch 92/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6391 - accuracy: 0.8317WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.8243 - lr: 0.1000
# Epoch 93/100
# 25/36 [===================>..........] - ETA: 0s - loss: 0.6542 - accuracy: 0.8288WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6568 - accuracy: 0.8304 - lr: 0.1000
# Epoch 94/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6493 - accuracy: 0.8274WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6493 - accuracy: 0.8274 - lr: 0.1000
# Epoch 95/100
# 29/36 [=======================>......] - ETA: 0s - loss: 0.6900 - accuracy: 0.8179WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 12ms/step - loss: 0.6701 - accuracy: 0.8265 - lr: 0.1000
# Epoch 96/100
# 26/36 [====================>.........] - ETA: 0s - loss: 0.6818 - accuracy: 0.8209WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6716 - accuracy: 0.8287 - lr: 0.1000
# Epoch 97/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.8252WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.8252 - lr: 0.1000
# Epoch 98/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6177 - accuracy: 0.8442WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6227 - accuracy: 0.8426 - lr: 0.1000
# Epoch 99/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.8378WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6460 - accuracy: 0.8378 - lr: 0.1000
# Epoch 100/100
# 36/36 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.8317WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,lr
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6248 - accuracy: 0.8317 - lr: 0.1000

# %%
final_model.save('final_model.h5')
import pickle
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)
with open('preprocessor.pkl', 'wb') as f:
    pickle.dump(preprocessor, f)
